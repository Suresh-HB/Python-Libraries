# %% [markdown]
# '''
#
# @Author: Suresh
# @Date: 2024-08-06
# @Last Modified by: Suresh
# @Last Modified: 2024-08-06
# @Title : Python programming to display a bar chart of the popularity of programming
# Languages.Use uniform color
#
# '''

# %%
import matplotlib.pyplot as plt
import pandas as pd
import myloggingfile as mlf
logger = mlf.logger_init("barsForgivenWidth_P8.ipynb")


def draw_bar_chart(data):

    """
    Description: Function to display a vertical bar chart of the popularity of programming 
                Languages with given width=0.6 . 
    Parameters:
       data : Function taking the data as a parameter to draw the barchart after make the data into data Frame
    Returns:
        None:
    """

    logger.info("inside draw_bar_chart")
    df = pd.DataFrame(data)
    logger.info(f" Data Frame\n{df}")

    plt.bar(df['programming'],df['popularity'],label='popularity',color='green',width=0.3)
    plt.xlabel("programming langauge")
    plt.ylabel("popularity")
    logger.info("labeling the x and y axis")
    plt.legend()
    logger.info("labeling plot label")
    plt.title("Popularity Of Programming Languages")

    plt.show()


def main():
    
    logger.info("Inside main method")

    data={
        'programming':['java','python','PHP','Javascript','C#','C++'],
        'popularity':[22.2,17.6,8.8,8,7.7,6.7]
        }
    
    logger.info("calling draw_bar_chart method")
    draw_bar_chart(data)


if __name__=='__main__':
    main()
# Out:
# 2024-08-06 17:31:33,990:INFO:barsForgivenWidth_P8.ipynb:Inside main method
# 2024-08-06 17:31:33,990:INFO:barsForgivenWidth_P8.ipynb:calling draw_bar_chart method
# 2024-08-06 17:31:33,990:INFO:barsForgivenWidth_P8.ipynb:inside draw_bar_chart
# 2024-08-06 17:31:34,005:INFO:barsForgivenWidth_P8.ipynb: Data Frame
#   programming  popularity
# 0        java        22.2
# 1      python        17.6
# 2         PHP         8.8
# 3  Javascript         8.0
# 4          C#         7.7
# 5         C++         6.7
# 2024-08-06 17:31:34,005:INFO:barsForgivenWidth_P8.ipynb:labeling the x and y axis
# 2024-08-06 17:31:34,005:INFO:barsForgivenWidth_P8.ipynb:labeling plot label
