# %% [markdown]
# @Author: Suresh
# @Date: 2024-07-31
# @Last Modified by: Suresh
# @Last Modified: 2024-07-31
# @Title : Python program to iterate over rows in a DataFrame.

# %%
import pandas as pd
import numpy as np
import myloggingfile

logger = myloggingfile.logger_init("add_age_column_P21.ipynb")

def adding_column(exam_data,labels):

    """
    Description: Function to Python program to add new column to the DataFrame.
    Parameters: 
        exam_data,labels : Function taking given data and it's lables to add new column to the data frame
    Returns:
        None:
    """

    logger.info(" inside adding_column method")

    df = pd.DataFrame(exam_data,labels) 
    for index, row in df.iterrows():
        print(f"Index: {index}")
        print(f"Name: {row['name']}")
        print(f"Score: {row['score']}")
        print(f"Attempts: {row['attempts']}")
        print(f"Qualify: {row['qualify']}")
        print() 
    


def main():
    
    logger.info(" inside main method")

    exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew',
    'Laura', 'Kevin', 'Jonas'],
    'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
    'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
    'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']
    }
    
    labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
    logger.info("calling adding_column method")
    adding_column(exam_data,labels)


if __name__=="__main__":
    main()
# Out:
# 2024-07-31 23:42:50,438:INFO:add_age_column_P21.ipynb: inside main method
# 2024-07-31 23:42:50,438:INFO:add_age_column_P21.ipynb: inside main method
# 2024-07-31 23:42:50,438:INFO:add_age_column_P21.ipynb: inside main method
# 2024-07-31 23:42:50,438:INFO:add_age_column_P21.ipynb: inside main method
# 2024-07-31 23:42:50,440:INFO:add_age_column_P21.ipynb:calling adding_column method
# 2024-07-31 23:42:50,440:INFO:add_age_column_P21.ipynb:calling adding_column method
# 2024-07-31 23:42:50,440:INFO:add_age_column_P21.ipynb:calling adding_column method
# 2024-07-31 23:42:50,440:INFO:add_age_column_P21.ipynb:calling adding_column method
# 2024-07-31 23:42:50,440:INFO:add_age_column_P21.ipynb: inside adding_column method
# 2024-07-31 23:42:50,440:INFO:add_age_column_P21.ipynb: inside adding_column method
# 2024-07-31 23:42:50,440:INFO:add_age_column_P21.ipynb: inside adding_column method
# 2024-07-31 23:42:50,440:INFO:add_age_column_P21.ipynb: inside adding_column method
# Index: a
# Name: Anastasia
# Score: 12.5
# Attempts: 1
# Qualify: yes
#
# Index: b
# Name: Dima
# Score: 9.0
# Attempts: 3
# Qualify: no
#
# Index: c
# Name: Katherine
# Score: 16.5
# Attempts: 2
# Qualify: yes
#
# Index: d
# Name: James
# Score: nan
# Attempts: 3
# Qualify: no
#
# Index: e
# Name: Emily
# Score: 9.0
# Attempts: 2
# Qualify: no
#
# Index: f
# Name: Michael
# Score: 20.0
# Attempts: 3
# Qualify: yes
#
# Index: g
# Name: Matthew
# Score: 14.5
# Attempts: 1
# Qualify: yes
#
# Index: h
# Name: Laura
# Score: nan
# Attempts: 1
# Qualify: no
#
# Index: i
# Name: Kevin
# Score: 8.0
# Attempts: 2
# Qualify: no
#
# Index: j
# Name: Jonas
# Score: 19.0
# Attempts: 1
# Qualify: yes
