# %% [markdown]
# '''
# @Author: Suresh
# @Date: 2024-08-02
# @Last Modified by: Suresh
# @Last Modified: 2024-08-02
# @Title : Write a Python program to plot two or more lines with different styles
#
# '''

# %%
import matplotlib.pyplot as plt
import pandas as pd
import myloggingfile as mlf

logger = mlf.logger_init("lineDifferentStyles_P7.ipynb")

def draw_line(data):

    """
    Description : Function to plot two or more lines with different styles
    Parameters : 
        data : Function that converts the data into a tabular format and then uses this
                data to plot the x-axis and y-axis.
    Returns :
        None :
    """

    logger.info("inside draw_line method")
    
    df = pd.DataFrame(data)
    logger.debug(f"\n{df}")

    plt.plot(df['Name'],df['Age'], color='blue', label ='line1-width-3', linestyle='-.',marker='o')
    plt.plot(df['Name'],df['Days'], color='green', label='line1-width-4', linestyle='-', marker='1')
    logger.info("plotting the results")

    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    logger.info("labellig the x-axis and y-axis")

    plt.legend()
    plt.grid()
    plt.show()


def main():

    logger.info("insdie main method")

    data = {
            'Name':['suresh','mahesh','tarun','sanju','sitaraman'],
            'Age':[23, 22, 23, 22, 18],
            'Days':[5, 8, 9, 6,3],
            'Company':['Apexon','QSG','Apexon','Apexon','info']
            }
    
    logger.info("calling draw_line method")
    draw_line(data)

if __name__ == '__main__':
    main()
# Out:
# 2024-08-02 21:32:30,117:INFO:differentWidths_P6.ipynbs:insdie main method
# 2024-08-02 21:32:30,117:INFO:differentWidths_P6.ipynbs:insdie main method
# 2024-08-02 21:32:30,117:INFO:differentWidths_P6.ipynbs:insdie main method
# 2024-08-02 21:32:30,117:INFO:differentWidths_P6.ipynbs:insdie main method
# 2024-08-02 21:32:30,117:INFO:differentWidths_P6.ipynbs:insdie main method
# 2024-08-02 21:32:30,117:INFO:differentWidths_P6.ipynbs:insdie main method
# 2024-08-02 21:32:30,117:INFO:differentWidths_P6.ipynbs:insdie main method
# 2024-08-02 21:32:30,117:INFO:differentWidths_P6.ipynbs:insdie main method
# 2024-08-02 21:32:30,117:INFO:differentWidths_P6.ipynbs:insdie main method
# 2024-08-02 21:32:30,117:INFO:differentWidths_P6.ipynbs:insdie main method
# 2024-08-02 21:32:30,117:INFO:differentWidths_P6.ipynbs:insdie main method
# 2024-08-02 21:32:30,117:INFO:differentWidths_P6.ipynbs:insdie main method
# 2024-08-02 21:32:30,117:INFO:differentWidths_P6.ipynbs:insdie main method
# 2024-08-02 21:32:30,131:INFO:differentWidths_P6.ipynbs:calling draw_line method
# 2024-08-02 21:32:30,131:INFO:differentWidths_P6.ipynbs:calling draw_line method
# 2024-08-02 21:32:30,131:INFO:differentWidths_P6.ipynbs:calling draw_line method
# 2024-08-02 21:32:30,131:INFO:differentWidths_P6.ipynbs:calling draw_line method
# 2024-08-02 21:32:30,131:INFO:differentWidths_P6.ipynbs:calling draw_line method
# 2024-08-02 21:32:30,131:INFO:differentWidths_P6.ipynbs:calling draw_line method
# 2024-08-02 21:32:30,131:INFO:differentWidths_P6.ipynbs:calling draw_line method
# 2024-08-02 21:32:30,131:INFO:differentWidths_P6.ipynbs:calling draw_line method
# 2024-08-02 21:32:30,131:INFO:differentWidths_P6.ipynbs:calling draw_line method
# 2024-08-02 21:32:30,131:INFO:differentWidths_P6.ipynbs:calling draw_line method
# 2024-08-02 21:32:30,131:INFO:differentWidths_P6.ipynbs:calling draw_line method
# 2024-08-02 21:32:30,131:INFO:differentWidths_P6.ipynbs:calling draw_line method
# 2024-08-02 21:32:30,131:INFO:differentWidths_P6.ipynbs:calling draw_line method
# 2024-08-02 21:32:30,134:INFO:differentWidths_P6.ipynbs:inside draw_line method
# 2024-08-02 21:32:30,134:INFO:differentWidths_P6.ipynbs:inside draw_line method
# 2024-08-02 21:32:30,134:INFO:differentWidths_P6.ipynbs:inside draw_line method
# 2024-08-02 21:32:30,134:INFO:differentWidths_P6.ipynbs:inside draw_line method
# 2024-08-02 21:32:30,134:INFO:differentWidths_P6.ipynbs:inside draw_line method
# 2024-08-02 21:32:30,134:INFO:differentWidths_P6.ipynbs:inside draw_line method
# 2024-08-02 21:32:30,134:INFO:differentWidths_P6.ipynbs:inside draw_line method
# 2024-08-02 21:32:30,134:INFO:differentWidths_P6.ipynbs:inside draw_line method
# 2024-08-02 21:32:30,134:INFO:differentWidths_P6.ipynbs:inside draw_line method
# 2024-08-02 21:32:30,134:INFO:differentWidths_P6.ipynbs:inside draw_line method
# 2024-08-02 21:32:30,134:INFO:differentWidths_P6.ipynbs:inside draw_line method
# 2024-08-02 21:32:30,134:INFO:differentWidths_P6.ipynbs:inside draw_line method
# 2024-08-02 21:32:30,134:INFO:differentWidths_P6.ipynbs:inside draw_line method
# 2024-08-02 21:32:30,163:DEBUG:differentWidths_P6.ipynbs:
#         Name  Age  Days Company
# 0     suresh   23     5  Apexon
# 1     mahesh   22     8     QSG
# 2      tarun   23     9  Apexon
# 3      sanju   22     6  Apexon
# 4  sitaraman   18     3    info
# 2024-08-02 21:32:30,163:DEBUG:differentWidths_P6.ipynbs:
#         Name  Age  Days Company
# 0     suresh   23     5  Apexon
# 1     mahesh   22     8     QSG
# 2      tarun   23     9  Apexon
# 3      sanju   22     6  Apexon
# 4  sitaraman   18     3    info
# 2024-08-02 21:32:30,163:DEBUG:differentWidths_P6.ipynbs:
#         Name  Age  Days Company
# 0     suresh   23     5  Apexon
# 1     mahesh   22     8     QSG
# 2      tarun   23     9  Apexon
# 3      sanju   22     6  Apexon
# 4  sitaraman   18     3    info
# 2024-08-02 21:32:30,163:DEBUG:differentWidths_P6.ipynbs:
#         Name  Age  Days Company
# 0     suresh   23     5  Apexon
# 1     mahesh   22     8     QSG
# 2      tarun   23     9  Apexon
# 3      sanju   22     6  Apexon
# 4  sitaraman   18     3    info
# 2024-08-02 21:32:30,163:DEBUG:differentWidths_P6.ipynbs:
#         Name  Age  Days Company
# 0     suresh   23     5  Apexon
# 1     mahesh   22     8     QSG
# 2      tarun   23     9  Apexon
# 3      sanju   22     6  Apexon
# 4  sitaraman   18     3    info
# 2024-08-02 21:32:30,163:DEBUG:differentWidths_P6.ipynbs:
#         Name  Age  Days Company
# 0     suresh   23     5  Apexon
# 1     mahesh   22     8     QSG
# 2      tarun   23     9  Apexon
# 3      sanju   22     6  Apexon
# 4  sitaraman   18     3    info
# 2024-08-02 21:32:30,163:DEBUG:differentWidths_P6.ipynbs:
#         Name  Age  Days Company
# 0     suresh   23     5  Apexon
# 1     mahesh   22     8     QSG
# 2      tarun   23     9  Apexon
# 3      sanju   22     6  Apexon
# 4  sitaraman   18     3    info
# 2024-08-02 21:32:30,163:DEBUG:differentWidths_P6.ipynbs:
#         Name  Age  Days Company
# 0     suresh   23     5  Apexon
# 1     mahesh   22     8     QSG
# 2      tarun   23     9  Apexon
# 3      sanju   22     6  Apexon
# 4  sitaraman   18     3    info
# 2024-08-02 21:32:30,163:DEBUG:differentWidths_P6.ipynbs:
#         Name  Age  Days Company
# 0     suresh   23     5  Apexon
# 1     mahesh   22     8     QSG
# 2      tarun   23     9  Apexon
# 3      sanju   22     6  Apexon
# 4  sitaraman   18     3    info
# 2024-08-02 21:32:30,163:DEBUG:differentWidths_P6.ipynbs:
#         Name  Age  Days Company
# 0     suresh   23     5  Apexon
# 1     mahesh   22     8     QSG
# 2      tarun   23     9  Apexon
# 3      sanju   22     6  Apexon
# 4  sitaraman   18     3    info
# 2024-08-02 21:32:30,163:DEBUG:differentWidths_P6.ipynbs:
#         Name  Age  Days Company
# 0     suresh   23     5  Apexon
# 1     mahesh   22     8     QSG
# 2      tarun   23     9  Apexon
# 3      sanju   22     6  Apexon
# 4  sitaraman   18     3    info
# 2024-08-02 21:32:30,163:DEBUG:differentWidths_P6.ipynbs:
#         Name  Age  Days Company
# 0     suresh   23     5  Apexon
# 1     mahesh   22     8     QSG
# 2      tarun   23     9  Apexon
# 3      sanju   22     6  Apexon
# 4  sitaraman   18     3    info
# 2024-08-02 21:32:30,163:DEBUG:differentWidths_P6.ipynbs:
#         Name  Age  Days Company
# 0     suresh   23     5  Apexon
# 1     mahesh   22     8     QSG
# 2      tarun   23     9  Apexon
# 3      sanju   22     6  Apexon
# 4  sitaraman   18     3    info
# 2024-08-02 21:32:30,195:INFO:differentWidths_P6.ipynbs:plotting the results
# 2024-08-02 21:32:30,195:INFO:differentWidths_P6.ipynbs:plotting the results
# 2024-08-02 21:32:30,195:INFO:differentWidths_P6.ipynbs:plotting the results
# 2024-08-02 21:32:30,195:INFO:differentWidths_P6.ipynbs:plotting the results
# 2024-08-02 21:32:30,195:INFO:differentWidths_P6.ipynbs:plotting the results
# 2024-08-02 21:32:30,195:INFO:differentWidths_P6.ipynbs:plotting the results
# 2024-08-02 21:32:30,195:INFO:differentWidths_P6.ipynbs:plotting the results
# 2024-08-02 21:32:30,195:INFO:differentWidths_P6.ipynbs:plotting the results
# 2024-08-02 21:32:30,195:INFO:differentWidths_P6.ipynbs:plotting the results
# 2024-08-02 21:32:30,195:INFO:differentWidths_P6.ipynbs:plotting the results
# 2024-08-02 21:32:30,195:INFO:differentWidths_P6.ipynbs:plotting the results
# 2024-08-02 21:32:30,195:INFO:differentWidths_P6.ipynbs:plotting the results
# 2024-08-02 21:32:30,195:INFO:differentWidths_P6.ipynbs:plotting the results
# 2024-08-02 21:32:30,203:INFO:differentWidths_P6.ipynbs:labellig the x-axis and y-axis
# 2024-08-02 21:32:30,203:INFO:differentWidths_P6.ipynbs:labellig the x-axis and y-axis
# 2024-08-02 21:32:30,203:INFO:differentWidths_P6.ipynbs:labellig the x-axis and y-axis
# 2024-08-02 21:32:30,203:INFO:differentWidths_P6.ipynbs:labellig the x-axis and y-axis
# 2024-08-02 21:32:30,203:INFO:differentWidths_P6.ipynbs:labellig the x-axis and y-axis
# 2024-08-02 21:32:30,203:INFO:differentWidths_P6.ipynbs:labellig the x-axis and y-axis
# 2024-08-02 21:32:30,203:INFO:differentWidths_P6.ipynbs:labellig the x-axis and y-axis
# 2024-08-02 21:32:30,203:INFO:differentWidths_P6.ipynbs:labellig the x-axis and y-axis
# 2024-08-02 21:32:30,203:INFO:differentWidths_P6.ipynbs:labellig the x-axis and y-axis
# 2024-08-02 21:32:30,203:INFO:differentWidths_P6.ipynbs:labellig the x-axis and y-axis
# 2024-08-02 21:32:30,203:INFO:differentWidths_P6.ipynbs:labellig the x-axis and y-axis
# 2024-08-02 21:32:30,203:INFO:differentWidths_P6.ipynbs:labellig the x-axis and y-axis
# 2024-08-02 21:32:30,203:INFO:differentWidths_P6.ipynbs:labellig the x-axis and y-axis
