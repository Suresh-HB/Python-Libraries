# %% [markdown]
# '''
# @Author: Suresh
# @Date: 2024-08-01
# @Last Modified by: Suresh
# @Last Modified: 2024-08-01
# @Title : Python program to draw a line with suitable label in the x axis, y axis and a title
#
# '''

# %%
import matplotlib.pyplot as plt
import myloggingfile as mlf

logger = mlf.logger_init("drawline_p1.ipynb")

def main():
 
    logger.info("Inside main method")
    
    x = [10,20,33,56,89,69,69]
    plt.plot(x)
    
    plt.xlabel("x")
    plt.ylabel("y")
    
    plt.show()

if __name__ =='__main__':
    main()
# Out:
# 2024-08-02 14:08:35,658:INFO:drawline_p1.ipynb:Inside main method
# 2024-08-02 14:08:35,658:INFO:drawline_p1.ipynb:Inside main method
# 2024-08-02 14:08:35,658:INFO:drawline_p1.ipynb:Inside main method
