# %% [markdown]
# '''
# @Author: Suresh
# @Date: 2024-08-02
# @Last Modified by: Suresh
# @Last Modified: 2024-08-02
# @Title : Python program to draw a line using given axis values taken from a text file, with suitable label in the x     axis, y axis and a title.
#
# '''

# %%
import matplotlib.pyplot as plt
import myloggingfile as mlf
import pandas as pd
 
logger = mlf.logger_init("finance_P4.ipynb")


def main():
    
    logger.info("inside main method")
    data = pd.read_csv('fdata.csv')
    logger.debug(f"data from fdata.csv file \n {data}")
    
    plt.plot(data['Date'],marker='o' )
    plt.grid(True)
    plt.show()
    

if __name__ == '__main__':
    main()
# Out:
# 2024-08-02 14:27:45,253:INFO:finance_P4.ipynb:inside main method
# 2024-08-02 14:27:45,258:DEBUG:finance_P4.ipynb:data from fdata.csv file
#         Date        Open        High         Low       Close
# 0  03-10-16  774.250000  776.065002  769.500000  772.559998
# 1  04-10-16  776.030029  778.710022  772.890015  776.429993
# 2  05-10-16  779.309998  782.070007  775.650024  776.469971
# 3  06-10-16  779.000000  780.479980  775.539978  776.859985
# 4  07-10-16  779.659973  779.659973  770.750000  775.080017
